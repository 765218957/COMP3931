# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
import pathlib

data_dir = './original_dataset/training'
data_dir = pathlib.Path(data_dir)
data_valid_dir = './original_dataset/validation'

# %%
image_count = len(list(data_dir.glob('*/*.jpg')))
print(image_count)
# Out:
# 8488

# %%
af = list(data_dir.glob('A/*'))
PIL.Image.open(str(af[0]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=561x420 at 0x1BC2ACA5BE0>

# %%
batch_size = 32
img_height = 320
img_width = 320

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 8488 files belonging to 4 classes.
# Using 6791 files for training.

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  data_valid_dir,
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 8488 files belonging to 4 classes.
# Using 1697 files for validation.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['A', 'N', 'O', '~']

# %%
for image_batch, labels_batch in train_ds:
    print(image_batch.shape)
    print(labels_batch.shape)
    break
# Out:
# (32, 320, 320, 3)
# (32,)

# %%
for image_batch, labels_batch in val_ds:
    print(image_batch.shape)
    print(labels_batch.shape)
    break

# %%
AUTOTUNE = tf.data.AUTOTUNE
print(AUTOTUNE)
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
normalization_layer = layers.Rescaling(1./255, input_shape=(img_height, img_width, 3))

# %%
num_classes = len(class_names)

model = Sequential([
  layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), #
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# rescaling (Rescaling)        (None, 320, 320, 3)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 320, 320, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 160, 160, 16)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 160, 160, 32)      4640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 80, 80, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 80, 80, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 40, 40, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 40, 40, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 102400)            0
# _________________________________________________________________
# dense (Dense)                (None, 128)               13107328
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 516
# =================================================================
# Total params: 13,131,428
# Trainable params: 13,131,428
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs=10
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/10
# 213/213 [==============================] - 13s 38ms/step - loss: 1.0889 - accuracy: 0.5868 - val_loss: 0.9583 - val_accuracy: 0.6022
# Epoch 2/10
# 213/213 [==============================] - 7s 34ms/step - loss: 0.9068 - accuracy: 0.5964 - val_loss: 0.8316 - val_accuracy: 0.6388
# Epoch 3/10
# 213/213 [==============================] - 7s 35ms/step - loss: 0.8153 - accuracy: 0.6438 - val_loss: 0.8314 - val_accuracy: 0.6529
# Epoch 4/10
# 213/213 [==============================] - 7s 34ms/step - loss: 0.7585 - accuracy: 0.6690 - val_loss: 0.7862 - val_accuracy: 0.6600
# Epoch 5/10
# 213/213 [==============================] - 7s 34ms/step - loss: 0.7167 - accuracy: 0.6958 - val_loss: 0.7872 - val_accuracy: 0.6688
# Epoch 6/10
# 213/213 [==============================] - 7s 34ms/step - loss: 0.6533 - accuracy: 0.7268 - val_loss: 0.7958 - val_accuracy: 0.6647
# Epoch 7/10
# 213/213 [==============================] - 7s 35ms/step - loss: 0.5652 - accuracy: 0.7710 - val_loss: 0.8469 - val_accuracy: 0.6364
# Epoch 8/10
# 213/213 [==============================] - 7s 35ms/step - loss: 0.4316 - accuracy: 0.8251 - val_loss: 0.9681 - val_accuracy: 0.6264
# Epoch 9/10
# 213/213 [==============================] - 8s 35ms/step - loss: 0.2976 - accuracy: 0.8847 - val_loss: 1.1023 - val_accuracy: 0.6346
# Epoch 10/10
# 213/213 [==============================] - 7s 35ms/step - loss: 0.2084 - accuracy: 0.9196 - val_loss: 1.2145 - val_accuracy: 0.6205

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
