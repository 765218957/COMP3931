# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
import pathlib

data_dir = './data/ECG_image/train'
data_dir = pathlib.Path(data_dir)

# %%
image_count = len(list(data_dir.glob('*/*.jpg')))
print(image_count)
# Out:
# 0

# %%
af = list(data_dir.glob('A/*'))
PIL.Image.open(str(af[0]))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-4-0be59ca07f37> in <module>
#       1 af = list(data_dir.glob('A/*'))
# ----> 2 PIL.Image.open(str(af[0]))
#
# IndexError: list index out of range

# %%
batch_size = 32
img_height = 180
img_width = 180

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 8497 files belonging to 4 classes.
# Using 6798 files for training.

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 8497 files belonging to 4 classes.
# Using 1699 files for validation.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['A', 'N', 'O', '~']

# %%
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (32, 180, 180, 3)
# (32,)

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
normalization_layer = layers.Rescaling(1./255)

# %%
num_classes = len(class_names)

model = Sequential([
  layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# rescaling_1 (Rescaling)      (None, 180, 180, 3)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 180, 180, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 90, 90, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 90, 90, 32)        4640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 45, 45, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 45, 45, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 22, 22, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 30976)             0
# _________________________________________________________________
# dense (Dense)                (None, 128)               3965056
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 516
# =================================================================
# Total params: 3,989,156
# Trainable params: 3,989,156
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs=10
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/10
# 213/213 [==============================] - 7s 15ms/step - loss: 0.9519 - accuracy: 0.5959 - val_loss: 0.8435 - val_accuracy: 0.6245
# Epoch 2/10
# 213/213 [==============================] - 3s 12ms/step - loss: 0.8131 - accuracy: 0.6447 - val_loss: 0.7932 - val_accuracy: 0.6639
# Epoch 3/10
# 213/213 [==============================] - 3s 12ms/step - loss: 0.7626 - accuracy: 0.6778 - val_loss: 0.7925 - val_accuracy: 0.6569
# Epoch 4/10
# 213/213 [==============================] - 3s 12ms/step - loss: 0.7143 - accuracy: 0.7031 - val_loss: 0.8024 - val_accuracy: 0.6410
# Epoch 5/10
# 213/213 [==============================] - 3s 12ms/step - loss: 0.6637 - accuracy: 0.7245 - val_loss: 0.8331 - val_accuracy: 0.6527
# Epoch 6/10
# 213/213 [==============================] - 3s 12ms/step - loss: 0.5909 - accuracy: 0.7610 - val_loss: 0.8455 - val_accuracy: 0.6727
# Epoch 7/10
# 213/213 [==============================] - 3s 12ms/step - loss: 0.4968 - accuracy: 0.8045 - val_loss: 0.9287 - val_accuracy: 0.6598
# Epoch 8/10
# 213/213 [==============================] - 3s 12ms/step - loss: 0.3784 - accuracy: 0.8567 - val_loss: 1.0762 - val_accuracy: 0.5992
# Epoch 9/10
# 213/213 [==============================] - 3s 12ms/step - loss: 0.2655 - accuracy: 0.8942 - val_loss: 1.2627 - val_accuracy: 0.6451
# Epoch 10/10
# 213/213 [==============================] - 3s 12ms/step - loss: 0.1839 - accuracy: 0.9287 - val_loss: 1.5232 - val_accuracy: 0.6351

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
data_augmentation = keras.Sequential(
  [
    layers.RandomFlip("horizontal",
                      input_shape=(img_height,
                                  img_width,
                                  3)),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
  ]
)

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
  for i in range(9):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")

# %%
model = Sequential([
  data_augmentation,
  layers.Rescaling(1./255),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# sequential_2 (Sequential)    (None, 180, 180, 3)       0
# _________________________________________________________________
# rescaling_2 (Rescaling)      (None, 180, 180, 3)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 180, 180, 16)      448
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 90, 90, 16)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 90, 90, 32)        4640
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 45, 45, 32)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 45, 45, 64)        18496
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 22, 22, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 22, 22, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 30976)             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               3965056
# _________________________________________________________________
# dense_3 (Dense)              (None, 4)                 516
# =================================================================
# Total params: 3,989,156
# Trainable params: 3,989,156
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 15
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/15
# 213/213 [==============================] - 4s 15ms/step - loss: 1.0452 - accuracy: 0.5815 - val_loss: 1.0185 - val_accuracy: 0.6027
# Epoch 2/15
# 213/213 [==============================] - 3s 14ms/step - loss: 1.0020 - accuracy: 0.5900 - val_loss: 0.9884 - val_accuracy: 0.6027
# Epoch 3/15
# 213/213 [==============================] - 3s 15ms/step - loss: 0.9869 - accuracy: 0.5911 - val_loss: 0.9841 - val_accuracy: 0.6080
# Epoch 4/15
# 213/213 [==============================] - 3s 15ms/step - loss: 0.9630 - accuracy: 0.5899 - val_loss: 0.9469 - val_accuracy: 0.6057
# Epoch 5/15
# 213/213 [==============================] - 3s 14ms/step - loss: 0.9460 - accuracy: 0.5924 - val_loss: 0.9265 - val_accuracy: 0.6221
# Epoch 6/15
# 213/213 [==============================] - 3s 14ms/step - loss: 0.9417 - accuracy: 0.5941 - val_loss: 0.9196 - val_accuracy: 0.6062
# Epoch 7/15
# 213/213 [==============================] - 3s 14ms/step - loss: 0.9350 - accuracy: 0.5983 - val_loss: 0.9096 - val_accuracy: 0.6157
# Epoch 8/15
# 213/213 [==============================] - 3s 14ms/step - loss: 0.9249 - accuracy: 0.5983 - val_loss: 0.9035 - val_accuracy: 0.6162
# Epoch 9/15
# 213/213 [==============================] - 3s 14ms/step - loss: 0.9263 - accuracy: 0.5991 - val_loss: 0.8949 - val_accuracy: 0.6145
# Epoch 10/15
# 213/213 [==============================] - 3s 14ms/step - loss: 0.9151 - accuracy: 0.6053 - val_loss: 0.9065 - val_accuracy: 0.5980
# Epoch 11/15
# 213/213 [==============================] - 3s 14ms/step - loss: 0.9136 - accuracy: 0.6071 - val_loss: 0.9009 - val_accuracy: 0.6098
# Epoch 12/15
# 213/213 [==============================] - 3s 14ms/step - loss: 0.9091 - accuracy: 0.6097 - val_loss: 0.8931 - val_accuracy: 0.6215
# Epoch 13/15
# 213/213 [==============================] - 3s 14ms/step - loss: 0.9084 - accuracy: 0.6040 - val_loss: 0.8810 - val_accuracy: 0.6186
# Epoch 14/15
# 213/213 [==============================] - 3s 15ms/step - loss: 0.9037 - accuracy: 0.6064 - val_loss: 0.8697 - val_accuracy: 0.6227
# Epoch 15/15
# 213/213 [==============================] - 3s 15ms/step - loss: 0.9021 - accuracy: 0.6108 - val_loss: 0.8790 - val_accuracy: 0.6251

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
