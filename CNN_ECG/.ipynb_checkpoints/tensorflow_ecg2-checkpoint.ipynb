# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
import pathlib

data_dir = './simulated_dataset/training'
data_dir = pathlib.Path(data_dir)
data_valid_dir = './simulated_dataset/validation'

# %%
image_count = len(list(data_dir.glob('*/*.jpg')))
print(image_count)
# Out:
# 8488

# %%
af = list(data_dir.glob('A/*'))
PIL.Image.open(str(af[0]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=561x420 at 0x1F3DFC33128>

# %%
batch_size = 32
img_height = 320
img_width = 320

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 8488 files belonging to 4 classes.

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  data_valid_dir,
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 297 files belonging to 4 classes.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['A', 'N', 'O', '~']

# %%
for image_batch, labels_batch in train_ds:
    print(image_batch.shape)
    print(labels_batch.shape)
    break
# Out:
# (32, 320, 320, 3)
# (32,)

# %%
for image_batch, labels_batch in val_ds:
    print(image_batch.shape)
    print(labels_batch.shape)
    break
# Out:
# (32, 320, 320, 3)
# (32,)

# %%
AUTOTUNE = tf.data.AUTOTUNE
print(AUTOTUNE)
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)
# Out:
# -1

# %%
normalization_layer = layers.Rescaling(1./255, input_shape=(img_height, img_width, 3))

# %%
num_classes = len(class_names)

model = Sequential([
  layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), #
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# rescaling_4 (Rescaling)      (None, 320, 320, 3)       0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 320, 320, 16)      448
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 160, 160, 16)      0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 160, 160, 32)      4640
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 80, 80, 32)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 80, 80, 64)        18496
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 40, 40, 64)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 40, 40, 64)        0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 102400)            0
# _________________________________________________________________
# dense_6 (Dense)              (None, 128)               13107328
# _________________________________________________________________
# dense_7 (Dense)              (None, 4)                 516
# =================================================================
# Total params: 13,131,428
# Trainable params: 13,131,428
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs=10
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/10
# 266/266 [==============================] - 13s 34ms/step - loss: 1.0370 - accuracy: 0.5878 - val_loss: 1.0789 - val_accuracy: 0.5152
# Epoch 2/10
# 266/266 [==============================] - 8s 32ms/step - loss: 0.8307 - accuracy: 0.6361 - val_loss: 0.9091 - val_accuracy: 0.6364
# Epoch 3/10
# 266/266 [==============================] - 9s 32ms/step - loss: 0.7598 - accuracy: 0.6737 - val_loss: 0.7983 - val_accuracy: 0.6801
# Epoch 4/10
# 266/266 [==============================] - 9s 32ms/step - loss: 0.7054 - accuracy: 0.7072 - val_loss: 0.7378 - val_accuracy: 0.7104
# Epoch 5/10
# 266/266 [==============================] - 8s 32ms/step - loss: 0.6554 - accuracy: 0.7349 - val_loss: 0.6871 - val_accuracy: 0.7542
# Epoch 6/10
# 266/266 [==============================] - 8s 32ms/step - loss: 0.5752 - accuracy: 0.7691 - val_loss: 0.5492 - val_accuracy: 0.8283
# Epoch 7/10
# 266/266 [==============================] - 9s 32ms/step - loss: 0.4700 - accuracy: 0.8102 - val_loss: 0.4159 - val_accuracy: 0.8822
# Epoch 8/10
# 266/266 [==============================] - 9s 32ms/step - loss: 0.3309 - accuracy: 0.8702 - val_loss: 0.3307 - val_accuracy: 0.9259
# Epoch 9/10
# 266/266 [==============================] - 9s 32ms/step - loss: 0.2086 - accuracy: 0.9214 - val_loss: 0.3149 - val_accuracy: 0.9293
# Epoch 10/10
# 266/266 [==============================] - 9s 32ms/step - loss: 0.1457 - accuracy: 0.9440 - val_loss: 0.3747 - val_accuracy: 0.9495

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
plt.figure(figsize=(8, 8))
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
