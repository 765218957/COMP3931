# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
import pathlib

data_dir = './ECG_image/training'
data_dir = pathlib.Path(data_dir)
data_valid_dir = './ECG_image/validation'

# %%
image_count = len(list(data_dir.glob('*/*.jpg')))
print(image_count)
# Out:
# 8049

# %%
af = list(data_dir.glob('A/*'))
PIL.Image.open(str(af[0]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x480 at 0x1C9346722E8>

# %%
batch_size = 32
img_height = 320
img_width = 320

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 8049 files belonging to 4 classes.

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  data_valid_dir,
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 282 files belonging to 4 classes.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['A', 'N', 'O', '~']

# %%
for image_batch, labels_batch in train_ds:
    print(image_batch.shape)
    print(labels_batch.shape)
    break
# Out:
# (32, 320, 320, 3)
# (32,)

# %%
for image_batch, labels_batch in val_ds:
    print(image_batch.shape)
    print(labels_batch.shape)
    break
# Out:
# (32, 320, 320, 3)
# (32,)

# %%
AUTOTUNE = tf.data.AUTOTUNE
print(AUTOTUNE)
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)
# Out:
# -1

# %%
normalization_layer = layers.Rescaling(1./255)

# %%
num_classes = len(class_names)

model = Sequential([
  layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes, activation='softmax')
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), #
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# rescaling_3 (Rescaling)      (None, 320, 320, 3)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 320, 320, 16)      448
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 160, 160, 16)      0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 160, 160, 32)      4640
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 80, 80, 32)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 80, 80, 64)        18496
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 40, 40, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 102400)            0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               13107328
# _________________________________________________________________
# dense_3 (Dense)              (None, 4)                 516
# =================================================================
# Total params: 13,131,428
# Trainable params: 13,131,428
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs=10
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/10
# 252/252 [==============================] - 12s 32ms/step - loss: 0.9122 - accuracy: 0.6234 - val_loss: 0.8592 - val_accuracy: 0.6170
# Epoch 2/10
# 252/252 [==============================] - 8s 32ms/step - loss: 0.7385 - accuracy: 0.6859 - val_loss: 0.7746 - val_accuracy: 0.6702
# Epoch 3/10
# 252/252 [==============================] - 8s 32ms/step - loss: 0.6468 - accuracy: 0.7351 - val_loss: 0.5818 - val_accuracy: 0.7801
# Epoch 4/10
# 252/252 [==============================] - 8s 32ms/step - loss: 0.5175 - accuracy: 0.7944 - val_loss: 0.4340 - val_accuracy: 0.8972
# Epoch 5/10
# 252/252 [==============================] - 8s 32ms/step - loss: 0.3445 - accuracy: 0.8692 - val_loss: 0.2122 - val_accuracy: 0.9220
# Epoch 6/10
# 252/252 [==============================] - 8s 32ms/step - loss: 0.2063 - accuracy: 0.9241 - val_loss: 0.1789 - val_accuracy: 0.9610
# Epoch 7/10
# 252/252 [==============================] - 8s 32ms/step - loss: 0.1152 - accuracy: 0.9601 - val_loss: 0.1542 - val_accuracy: 0.9645
# Epoch 8/10
# 252/252 [==============================] - 8s 32ms/step - loss: 0.0654 - accuracy: 0.9790 - val_loss: 0.1274 - val_accuracy: 0.9681
# Epoch 9/10
# 252/252 [==============================] - 8s 32ms/step - loss: 0.0482 - accuracy: 0.9875 - val_loss: 0.1026 - val_accuracy: 0.9894
# Epoch 10/10
# 252/252 [==============================] - 8s 32ms/step - loss: 0.0259 - accuracy: 0.9948 - val_loss: 0.1234 - val_accuracy: 0.9681

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
