# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
import pathlib

data_dir = './original_dataset/training'
data_dir = pathlib.Path(data_dir)
data_valid_dir = './original_dataset/validation'

# %%
image_count = len(list(data_dir.glob('*/*.jpg')))
print(image_count)
# Out:
# 8483

# %%
af = list(data_dir.glob('A/*'))
PIL.Image.open(str(af[0]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x480 at 0x2548F3C8BE0>

# %%
batch_size = 32
img_height = 320
img_width = 320

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 8483 files belonging to 4 classes.

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  data_valid_dir,
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 297 files belonging to 4 classes.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['A', 'N', 'O', '~']

# %%
for image_batch, labels_batch in train_ds:
    print(image_batch.shape)
    print(labels_batch.shape)
    break
# Out:
# (32, 320, 320, 3)
# (32,)

# %%
for image_batch, labels_batch in val_ds:
    print(image_batch.shape)
    print(labels_batch.shape)
    break
# Out:
# (32, 320, 320, 3)
# (32,)

# %%
AUTOTUNE = tf.data.AUTOTUNE
print(AUTOTUNE)
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)
# Out:
# -1

# %%
normalization_layer = layers.Rescaling(1./255, input_shape=(img_height, img_width, 3))

# %%
num_classes = len(class_names)

model = Sequential([
  layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), #
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# rescaling_1 (Rescaling)      (None, 320, 320, 3)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 320, 320, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 160, 160, 16)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 160, 160, 32)      4640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 80, 80, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 80, 80, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 40, 40, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 40, 40, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 102400)            0
# _________________________________________________________________
# dense (Dense)                (None, 128)               13107328
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 516
# =================================================================
# Total params: 13,131,428
# Trainable params: 13,131,428
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs=10
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/10
# 266/266 [==============================] - 15s 34ms/step - loss: 1.0731 - accuracy: 0.5826 - val_loss: 1.2518 - val_accuracy: 0.5051
# Epoch 2/10
# 266/266 [==============================] - 8s 32ms/step - loss: 0.9716 - accuracy: 0.5955 - val_loss: 1.1560 - val_accuracy: 0.5185
# Epoch 3/10
# 266/266 [==============================] - 8s 32ms/step - loss: 0.8326 - accuracy: 0.6364 - val_loss: 0.9049 - val_accuracy: 0.6061
# Epoch 4/10
# 266/266 [==============================] - 8s 32ms/step - loss: 0.7541 - accuracy: 0.6775 - val_loss: 0.7879 - val_accuracy: 0.7071
# Epoch 5/10
# 266/266 [==============================] - 8s 32ms/step - loss: 0.6900 - accuracy: 0.7144 - val_loss: 0.7064 - val_accuracy: 0.7441
# Epoch 6/10
# 266/266 [==============================] - 8s 32ms/step - loss: 0.6261 - accuracy: 0.7422 - val_loss: 0.6076 - val_accuracy: 0.7879
# Epoch 7/10
# 266/266 [==============================] - 8s 32ms/step - loss: 0.5602 - accuracy: 0.7727 - val_loss: 0.5244 - val_accuracy: 0.8148
# Epoch 8/10
# 266/266 [==============================] - 8s 32ms/step - loss: 0.4776 - accuracy: 0.8074 - val_loss: 0.3930 - val_accuracy: 0.8822
# Epoch 9/10
# 266/266 [==============================] - 8s 32ms/step - loss: 0.3710 - accuracy: 0.8525 - val_loss: 0.3786 - val_accuracy: 0.8889
# Epoch 10/10
# 266/266 [==============================] - 8s 32ms/step - loss: 0.2727 - accuracy: 0.8941 - val_loss: 0.3543 - val_accuracy: 0.9360

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
